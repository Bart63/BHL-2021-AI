# %%
import pandas as pd
df = pd.read_csv('data/final_train.csv')
pd.set_option('display.max_columns', None)

# %%
df.shape
# Out:
# (11086, 573)

# %%
df.sample(4)
# Out:
#        Unnamed: 0            Activity  angle(X,gravityMean)  \
# 2331         2331  WALKING_DOWNSTAIRS             -1.573357
# 1262         1262              LAYING             -1.548333
# 9457         9457    WALKING_UPSTAIRS             -1.568669
# 10061       10061  WALKING_DOWNSTAIRS             -1.569172
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2331              -0.811134             -2.447201
# 1262              -0.139628             -2.380889
# 9457              -0.612620             -2.488338
# 10061             -0.886931             -2.480339
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyAccMean,gravity)  \
# 2331                              -1.992087                     0.640254
# 1262                              -1.915239                     0.067613
# 9457                              -1.751117                     0.218134
# 10061                             -1.782007                    -0.496139
#
# ...

# %% [markdown]
# ## Wybieramy tylko te kolumny które uwzględniają średnią i odchylenie standardowe

# %%
mean_cols = [col for col in df.columns if 'mean' in col or 'Mean' in col]
std_cols = [col for col in df.columns if 'std' in col or 'Std' in col]

# %%
df_mean = df[mean_cols]

# %%
df_std = df[std_cols]

# %%
df_new = pd.concat([df_std, df_mean], axis = 1)

# %% [markdown]
# ## Usuwamy kolumny zawierające kąt i energię i średnią częstotliwości

# %%
angle_cols = [col for col in df_new.columns if 'angle' in col or 'Angle' in col]
energy_cols = [col for col in df_new.columns if 'energy' in col or 'Energy' in col]
meanFreq_cols = [col for col in df_new.columns if 'meanFreq' in col]
drop_cols = angle_cols + energy_cols + meanFreq_cols
drop_cols
# Out:
# ['angle(X,gravityMean)',
#  'angle(Y,gravityMean)',
#  'angle(Z,gravityMean)',
#  'angle(tBodyAccJerkMean),gravityMean)',
#  'angle(tBodyAccMean,gravity)',
#  'angle(tBodyGyroJerkMean,gravityMean)',
#  'angle(tBodyGyroMean,gravityMean)',
#  'energy-mean()',
#  'fBodyAcc-meanFreq()-X',
#  'fBodyAcc-meanFreq()-Y',
#  'fBodyAcc-meanFreq()-Z',
#  'fBodyAccJerk-meanFreq()-X',
#  'fBodyAccJerk-meanFreq()-Y',
#  'fBodyAccJerk-meanFreq()-Z',
#  'fBodyAccMag-meanFreq()',
#  'fBodyBodyAccJerkMag-meanFreq()',
#  'fBodyBodyGyroJerkMag-meanFreq()',
#  'fBodyBodyGyroMag-meanFreq()',
#  'fBodyGyro-meanFreq()-X',
#  'fBodyGyro-meanFreq()-Y',
#  'fBodyGyro-meanFreq()-Z']

# %%
df_new = df_new.drop(drop_cols, axis=1)

# %% [markdown]
# Dodajemy labele

# %%
df_new = pd.concat([df.Activity, df_new], axis = 1)

# %% [markdown]
# ## Nowe dane

# %%
df_new.sample(4)
# Out:
#                Activity  fBodyAcc-std()-X  fBodyAcc-std()-Y  fBodyAcc-std()-Z  \
# 10270  WALKING_UPSTAIRS         -0.812567         -3.333018          3.880430
# 7491             LAYING          0.755296         -1.283612          4.217478
# 126             SITTING          0.800740         -1.263615          4.218484
# 6786             LAYING          0.755296         -1.283612          4.217478
#
#        fBodyAccJerk-std()-X  fBodyAccJerk-std()-Y  fBodyAccJerk-std()-Z  \
# 10270             -5.363913              1.599676              2.009346
# 7491              -4.063730              0.303414              2.333802
# 126               -4.025662              0.265277              2.359055
# 6786              -4.063730              0.303414              2.333802
#
#        fBodyAccMag-std()  fBodyBodyAccJerkMag-std()  \
# 10270          -2.428577                  -2.924506
# 7491           -0.806943                  -3.011841
# 126            -0.784989                  -3.015987
# ...

# %%
df_new.shape
# Out:
# (11086, 67)

# %% [markdown]
# Uncomment to export

# %%
df_new.to_csv('data/df_nan.csv', index = False)

# %%
df_no_nan = df_new.dropna()
df_no_nan.sample(4)
# Out:
#                 Activity  fBodyAcc-std()-X  fBodyAcc-std()-Y  \
# 953             STANDING          0.796155         -1.294305
# 6049  WALKING_DOWNSTAIRS         -1.583587         -2.903809
# 3339              LAYING          0.788916         -1.265317
# 5750              LAYING          0.755296         -1.283612
#
#       fBodyAcc-std()-Z  fBodyAccJerk-std()-X  fBodyAccJerk-std()-Y  \
# 953           4.209145             -4.039502              0.295632
# 6049          3.892378             -6.197700              2.370148
# 3339          4.201182             -4.039550              0.298023
# 5750          4.217478             -4.063730              0.303414
#
#       fBodyAccJerk-std()-Z  fBodyAccMag-std()  fBodyBodyAccJerkMag-std()  \
# 953               2.347766          -0.794992                  -3.014780
# 6049              1.744770          -3.015562                  -2.861805
# 3339              2.343071          -0.813645                  -3.013819
# ...

# %%
df_no_nan.shape
# Out:
# (9826, 67)

# %% [markdown]
# Uncomment to export

# %%
df_no_nan.to_csv('data/df_no_nan.csv', index = False)
