# %%
import pandas as pd

# %%
df = pd.read_csv('data/final_train.csv')

# %%
df.sample(40)
df.columns
# Out:
# Index(['Unnamed: 0', 'Activity', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)',
#        'angle(tBodyAccJerkMean),gravityMean)', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyGyroJerkMean,gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)', 'energy-mean()',
#        ...
#        'tGravityAccMag-energy()', 'tGravityAccMag-entropy()',
#        'tGravityAccMag-iqr()', 'tGravityAccMag-mad()', 'tGravityAccMag-max()',
#        'tGravityAccMag-mean()', 'tGravityAccMag-min()', 'tGravityAccMag-sma()',
#        'tGravityAccMag-std()', 'void()'],
#       dtype='object', length=573)

# %%
df.shape
# Out:
# (11086, 573)

# %%
df.head(10)
# Out:
#    Unnamed: 0            Activity  angle(X,gravityMean)  angle(Y,gravityMean)  \
# 0           0            STANDING             -1.574191             -0.805700
# 1           1    WALKING_UPSTAIRS             -1.568669             -0.612620
# 2           2              LAYING             -1.548333             -0.139628
# 3           3             WALKING             -1.574094             -0.793443
# 4           4              LAYING             -1.548333             -0.139628
# 5           5             SITTING             -1.575809             -0.640703
# 6           6              LAYING             -1.544632             -0.082690
# 7           7            STANDING             -1.567323             -0.857850
# 8           8              LAYING             -1.548536             -0.085978
# 9           9  WALKING_DOWNSTAIRS             -1.574517             -0.779927
#
#    angle(Z,gravityMean)  angle(tBodyAccJerkMean),gravityMean)  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  angle(X,gravityMean)  angle(Y,gravityMean)  \
# count  11086.000000          11029.000000          11018.000000
# mean    5542.500000             -1.566818             -0.615862
# std     3200.396876              0.009901              0.330366
# min        0.000000             -1.577122             -1.839413
# 25%     2771.250000             -1.573312             -0.850689
# 50%     5542.500000             -1.570783             -0.726956
# 75%     8313.750000             -1.567797             -0.468971
# max    11085.000000             -1.536682              0.720197
#
#        angle(Z,gravityMean)  angle(tBodyAccJerkMean),gravityMean)  \
# count          11026.000000                          11034.000000
# mean              -2.446177                             -1.860175
# std                0.033629                              0.070504
# min               -2.562914                             -2.012415
# ...

# %%
df.shape
# Out:
# (11086, 573)

# %% [markdown]
# pozbyć się niekompletnych wierszy można tak

# %%
df.dropna().shape
# Out:
# (9624, 573)

# %%
pd.set_option('display.max_columns', None)
df.sample(5)
# Out:
#        Unnamed: 0          Activity  angle(X,gravityMean)  \
# 9764         9764           SITTING             -1.574905
# 7624         7624           SITTING             -1.570374
# 7644         7644           SITTING             -1.572165
# 2284         2284  WALKING_UPSTAIRS             -1.568669
# 10586       10586  WALKING_UPSTAIRS             -1.567222
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 9764                    NaN             -2.449443
# 7624              -0.807312             -2.432511
# 7644              -0.559539             -2.439673
# 2284              -0.612620             -2.488338
# 10586             -0.891096             -2.488850
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyAccMean,gravity)  \
# 9764                              -1.780907                     0.108242
# 7624                              -1.836867                     0.150060
# 7644                              -1.833424                     0.010802
# ...

# %% [markdown]
# ## poszczególne aktywności

# %%
pd.unique(df['Activity'])
# Out:
# array(['STANDING', 'WALKING_UPSTAIRS', 'LAYING', 'WALKING', 'SITTING',
#        'WALKING_DOWNSTAIRS'], dtype=object)

# %%
body_cols = [col for col in df.columns if 'Body' in col]
len(time_cols)
# Out:
# 511

# %%
511/573
# Out:
# 0.8917975567190227

# %% [markdown]
# 89% kolumn odnosi się do ?smartfona?

# %% [markdown]
# ## aktywnosci

# %%
standing = df.loc[df['Activity'] == 'STANDING']

# %%
walking_upstairs = df.loc[df['Activity'] == 'WALKING_UPSTAIRS']

# %%
laying = df.loc[df['Activity'] == 'LAYING']

# %%
walking = df.loc[df['Activity'] == 'WALKING']

# %%
sitting = df.loc[df['Activity'] == 'SITTING']

# %%
walking_downstairs = df.loc[df['Activity'] == 'WALKING_DOWNSTAIRS']

# %% [markdown]
# ## kolumny nie zawierające 'Body'

# %%
other_cols = [col for col in df.columns if 'Body' not in col]
other_cols
# Out:
# ['Unnamed: 0',
#  'Activity',
#  'angle(X,gravityMean)',
#  'angle(Y,gravityMean)',
#  'angle(Z,gravityMean)',
#  'energy-mean()',
#  'shadow-gravity-angle()',
#  'subject',
#  'tGravityAcc-arCoeff()-X,1',
#  'tGravityAcc-arCoeff()-X,2',
#  'tGravityAcc-arCoeff()-X,3',
#  'tGravityAcc-arCoeff()-X,4',
#  'tGravityAcc-arCoeff()-Y,1',
#  'tGravityAcc-arCoeff()-Y,2',
#  'tGravityAcc-arCoeff()-Y,3',
#  'tGravityAcc-arCoeff()-Y,4',
#  'tGravityAcc-arCoeff()-Z,1',
#  'tGravityAcc-arCoeff()-Z,2',
#  'tGravityAcc-arCoeff()-Z,3',
#  'tGravityAcc-arCoeff()-Z,4',
#  'tGravityAcc-correlation()-X,Y',
#  'tGravityAcc-correlation()-X,Z',
#  'tGravityAcc-correlation()-Y,Z',
#  'tGravityAcc-energy()-X',
#  'tGravityAcc-energy()-Y',
#  'tGravityAcc-energy()-Z',
#  'tGravityAcc-entropy()-X',
#  'tGravityAcc-entropy()-Y',
#  'tGravityAcc-entropy()-Z',
#  'tGravityAcc-iqr()-X',
#  'tGravityAcc-iqr()-Y',
#  'tGravityAcc-iqr()-Z',
#  'tGravityAcc-mad()-X',
#  'tGravityAcc-mad()-Y',
# ...

# %%
mean_cols = [col for col in df.columns if 'mean' in col or 'Mean' in col]
std_cols = [col for col in df.columns if 'std' in col or 'Std' in col]

len(mean_cols + std_cols)
# Out:
# 87

# %%
df['Activity'].value_counts()
# Out:
# LAYING                2167
# SITTING               2019
# STANDING              1979
# WALKING               1900
# WALKING_UPSTAIRS      1633
# WALKING_DOWNSTAIRS    1388
# Name: Activity, dtype: int64

# %% [markdown]
# Najwięcej studentów leży
